# %% [markdown]
# # Citrine data retrieval example: get experimental band gaps of PbTe from Citrine

# %% [markdown]
# This notebook demonstrates use of the code **'retrieve_Citrine.py'** in retrieving data from various datasets collected by Citrine Informatics at http://citrination.com/, and output it in the form of a Pandas dataframe. In this example, we query the Citrine API to retrieve all experimental band gaps of PbTe available in the database of Citrine.

# %% [markdown]
# ## Preamble
#
# ### Set pandas options to display all rows and columns

# %%
import pandas as pd

pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Step 1:
#
# ### Import matminer's Citrine data retrieval tool, and retrieve all experimental band gaps of "PbTe" from Citrine's database in a Pandas dataframe.

# %%
from matminer.data_retrieval.retrieve_Citrine import CitrineDataRetrieval

api_key = None       # Set your Citrine API key here. If set as an environment variable 'CITRINE_KEY', set it to 'None'
c = CitrineDataRetrieval(api_key)     # Create an adapter to the Citrine Database.

df = c.get_dataframe(formula='PbTe', property='band gap', data_type='experimental')
df
# Out:
# /Users/sbajaj/.local/lib/python2.7/site-packages/citrination_client/search/pif/query/chemical/chemical_field_operation.py:19: UserWarning: ChemicalFieldOperation has been deprecated in favor of ChemicalFieldQuery starting with version 1.3.0
#   warn("ChemicalFieldOperation has been deprecated in favor of ChemicalFieldQuery starting with version 1.3.0")
# /Users/sbajaj/.local/lib/python2.7/site-packages/citrination_client/search/pif/query/core/field_operation.py:19: UserWarning: FieldOperation has been deprecated in favor of FieldQuery starting with version 1.3.0
#   warn("FieldOperation has been deprecated in favor of FieldQuery starting with version 1.3.0")
# /Users/sbajaj/.local/lib/python2.7/site-packages/pypif/obj/common/property.py:78: UserWarning: method has been deprecated in favor of methods
#   warn("method has been deprecated in favor of methods")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7258d810b9fd> in <module>()
#       4 c = CitrineDataRetrieval(api_key)     # Create an adapter to the Citrine Database.
#       5
# ----> 6 df = c.get_dataframe(formula='PbTe', property='band gap', data_type='experimental')
#       7 df
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/matminer/data_retrieval/retrieve_Citrine.pyc in get_dataframe(self, formula, property, data_type, reference, min_measurement, max_measurement, from_record, data_set_id, max_results, show_columns)
#     162
#     163             # Check if any results found
# --> 164             if 'hits' not in self.client.search(pif_query).as_dictionary():
#     165                 raise KeyError('No results found!')
#     166
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/citrination_client/client.pyc in search(self, pif_query)
#      64         if response.status_code != requests.codes.ok:
#      65             raise RuntimeError('Received ' + str(response.status_code) + ' response: ' + str(response.reason))
# ---> 66         return PifSearchResult(**keys_to_snake_case(response.json()['results']))
#      67
#      68     def pif_multi_search(self, pif_multi_query):
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/citrination_client/search/pif/result/pif_search_result.pyc in __init__(self, took, total_num_hits, hits)
#      21         self.total_num_hits = total_num_hits
#      22         self._hits = None
# ---> 23         self.hits = hits
#      24
#      25     @property
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/citrination_client/search/pif/result/pif_search_result.pyc in hits(self, hits)
#      53     @hits.setter
#      54     def hits(self, hits):
# ---> 55         self._hits = self._get_object(PifSearchHit, hits)
#      56
#      57     @hits.deleter
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/pypif/util/serializable.pyc in _get_object(class_, obj)
#      43         """
#      44         if isinstance(obj, list):
# ---> 45             return [Serializable._get_object(class_, i) for i in obj]
#      46         elif isinstance(obj, dict):
#      47             return class_(**keys_to_snake_case(obj))
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/pypif/util/serializable.pyc in _get_object(class_, obj)
#      45             return [Serializable._get_object(class_, i) for i in obj]
#      46         elif isinstance(obj, dict):
# ---> 47             return class_(**keys_to_snake_case(obj))
#      48         else:
#      49             return obj
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/citrination_client/search/pif/result/pif_search_hit.pyc in __init__(self, id, dataset, dataset_version, score, system, extracted)
#      30         self.score = score
#      31         self._system = None
# ---> 32         self.system = system
#      33         self._extracted = None
#      34         self.extracted = extracted
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/citrination_client/search/pif/result/pif_search_hit.pyc in system(self, system)
#      93             self._system = pif.loads(system)
#      94         elif isinstance(system, dict):
# ---> 95             self._system = pif.loado(system)
#      96         elif isinstance(system, Pio):
#      97             self._system = system
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/pypif/pif.pyc in loado(obj)
#      59         return [_dict_to_pio(i) for i in obj]
#      60     elif isinstance(obj, dict):
# ---> 61         return _dict_to_pio(obj)
#      62     else:
#      63         raise ValueError('expecting list or dictionary as outermost structure')
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/pypif/pif.pyc in _dict_to_pio(d)
#      77         return System(**d)
#      78     elif d['category'] == 'system.chemical':
# ---> 79         return ChemicalSystem(**d)
#      80     elif d['category'] == 'system.chemical.alloy':  # Legacy support
#      81         return Alloy(**d)
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/pypif/obj/system/chemical/chemical_system.pyc in __init__(self, uid, names, ids, classifications, source, quantity, chemical_formula, composition, properties, preparation, sub_systems, references, contacts, licenses, tags, **kwargs)
#      41                                              source=source, quantity=quantity, properties=properties,
#      42                                              preparation=preparation, sub_systems=sub_systems, references=references,
# ---> 43                                              contacts=contacts, licenses=licenses, tags=tags, **kwargs)
#      44         self._chemical_formula = None
#      45         self.chemical_formula = chemical_formula
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/pypif/obj/system/system.pyc in __init__(self, uid, names, ids, classifications, source, quantity, properties, preparation, sub_systems, references, contacts, licenses, tags, **kwargs)
#      55         self.quantity = quantity
#      56         self._properties = None
# ---> 57         self.properties = properties
#      58         self._preparation = None
#      59         self.preparation = preparation
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/pypif/obj/system/system.pyc in properties(self, properties)
#     147     def properties(self, properties):
#     148         self._validate_list_type('properties', properties, dict, Property)
# --> 149         self._properties = self._get_object(Property, properties)
#     150
#     151     @properties.deleter
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/pypif/util/serializable.pyc in _get_object(class_, obj)
#      43         """
#      44         if isinstance(obj, list):
# ---> 45             return [Serializable._get_object(class_, i) for i in obj]
#      46         elif isinstance(obj, dict):
#      47             return class_(**keys_to_snake_case(obj))
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/pypif/util/serializable.pyc in _get_object(class_, obj)
#      45             return [Serializable._get_object(class_, i) for i in obj]
#      46         elif isinstance(obj, dict):
# ---> 47             return class_(**keys_to_snake_case(obj))
#      48         else:
#      49             return obj
#
# /Users/sbajaj/.local/lib/python2.7/site-packages/pypif/obj/common/property.pyc in __init__(self, name, scalars, vectors, matrices, files, units, conditions, methods, data_type, references, contacts, licenses, tags, **kwargs)
#      48         self.conditions = conditions
#      49         if 'method' in kwargs:
# ---> 50             self.methods = method
#      51         self._methods = None
#      52         self.methods = methods
#
# NameError: global name 'method' is not defined

# %% [markdown]
# ## Step 2:
#
# ### Filter out rows with null values of band gap

# %%
import numpy as np

df = df[np.isfinite(df['Band gap'])]
df
# Out:
#        chemicalFormula                                         references  Band gap Color Crystallinity Electroluminescence Lasing Morphology Photoluminescence  Temperature derivative of band gap Thermoluminescence                                         conditions      dataType                           method units
# system
# 1               Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.290   NaN          None                None    NaN        NaN              None                                 NaN               None  [{u'scalars': [{'value': u'Indirect'}], u'name...  EXPERIMENTAL         {u'name': u'Reflection'}    eV
# 2               Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.217   NaN          None                 NaN    NaN       None               NaN                                 NaN                NaN  [{u'scalars': [{'value': u'Direct'}], u'name':...  EXPERIMENTAL  {u'name': u'Magnetoabsorption'}    eV
# 3               Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.210   NaN          None                None    NaN        NaN              None                                 NaN               None  [{u'scalars': [{'value': u'Indirect'}], u'name...  EXPERIMENTAL         {u'name': u'Reflection'}    eV
# 4               Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.290   NaN          None                 NaN    NaN        NaN               NaN                                 NaN                NaN  [{u'scalars': [{'value': u'Indirect'}], u'name...  EXPERIMENTAL         {u'name': u'Absorption'}    eV
# 5               Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.190   NaN          None                 NaN    NaN       None               NaN                                 NaN                NaN  [{u'scalars': [{'value': u'Direct'}], u'name':...  EXPERIMENTAL  {u'name': u'Magnetoabsorption'}    eV
# 6               Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.340   NaN          None                 NaN    NaN       None               NaN                                 NaN                NaN  [{u'scalars': [{'value': u'Direct'}], u'name':...  EXPERIMENTAL         {u'name': u'Reflection'}    eV
# 7               Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.320   NaN          None                 NaN    NaN        NaN               NaN                                 NaN                NaN  [{u'scalars': [{'value': u'Direct'}], u'name':...  EXPERIMENTAL         {u'name': u'Absorption'}    eV
# 8               Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.210  None          None                 NaN    NaN        NaN               NaN                                 NaN                NaN  [{u'scalars': [{'value': u'Direct'}], u'name':...  EXPERIMENTAL    {u'name': u'Photoconduction'}    eV
# 9               Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.190   NaN          None                 NaN    NaN        NaN               NaN                                 NaN                NaN  [{u'scalars': [{'value': u'Indirect'}], u'name...  EXPERIMENTAL         {u'name': u'Absorption'}    eV
# 10              Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.185  None          None                 NaN    NaN        NaN               NaN                                 NaN                NaN  [{u'scalars': [{'value': u'Direct'}], u'name':...  EXPERIMENTAL    {u'name': u'Photoconduction'}    eV
# 11              Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.310   NaN          None                 NaN    NaN       None               NaN                                 NaN                NaN  [{u'scalars': [{'value': u'Direct'}], u'name':...  EXPERIMENTAL         {u'name': u'Reflection'}    eV
# 12              Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.191   NaN          None                 NaN   None        NaN               NaN                                 NaN                NaN  [{u'units': u'K', u'scalars': [{'value': u'4.2...  EXPERIMENTAL                              NaN    eV
# 13              Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.190   NaN          None                 NaN    NaN        NaN               NaN                                 NaN                NaN  [{u'scalars': [{'value': u'Direct'}], u'name':...  EXPERIMENTAL         {u'name': u'Reflection'}    eV
# 14              Pb1Te1  [{u'doi': u'10.1063/1.3253115', u'citation': u...     0.310  None          None                 NaN    NaN        NaN               NaN                                 NaN                NaN  [{u'scalars': [{'value': u'Direct'}], u'name':...  EXPERIMENTAL    {u'name': u'Photoconduction'}    eV

# %% [markdown]
# ## Step 3:
#
# ### Get basic statistics

# %%
df['Band gap'].describe()
# Out:
# count    14.000000
# mean      0.245929
# std       0.059461
# min       0.185000
# 25%       0.190250
# 50%       0.213500
# 75%       0.305000
# max       0.340000
# Name: Band gap, dtype: float64
